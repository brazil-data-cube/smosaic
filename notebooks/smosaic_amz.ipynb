# %%
import os
from smosaic import open_geojson, mosaic

# %%
path_dir = os.path.abspath("")

# %%
geometry = open_geojson('brazil.json')

# %%
result = mosaic(
    data_dir=os.path.join(path_dir),
    collection="AMZ1-WFI-L4-SR-1", 
    geom=geometry,
    output_dir=os.path.join(path_dir, "output"),   
    mosaic_method="lcf", 
    start_year=2025,
    start_month=1,
    start_day=1,
    duration_months=5, 
    bands=["BAND3","BAND4","CMASK"]
)
