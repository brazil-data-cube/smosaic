# %%
import os
from smosaic import collection_query, collection_get_data

# %%
path_dir = os.path.abspath("")

# %%
collection=collection_query(
    collection="AMZ1-WFI-L4-SR-1",
    start_date="2025-01-01",
    end_date="2025-05-31",
    bbox="-74.8828,-34.5970,-31.8164,5.5285",
    bands=["BAND3","BAND4","CMASK"]
)

# %%
collection_get_data(collection)
# Out:
# Downloading... : 100%|██████████| 659/659 [02:08<00:00,  5.11itens/s]
# Successfully download 659 files to /AMZ1-WFI-L4-SR-1
