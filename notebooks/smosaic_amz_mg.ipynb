# %%
import os
from smosaic import mosaic

# %%
path_dir = os.path.abspath("")

# %%
result = mosaic(
    name="minas-gerais",
    data_dir=os.path.join(path_dir),
    collection="AMZ1-WFI-L4-SR-1", 
    grid="br_states",
    grid_id="MG",
    output_dir=os.path.join(path_dir, "output"),   
    mosaic_method="lcf", 
    start_year=2025,
    start_month=1,
    start_day=1,
    duration_months=5, 
    bands=["BAND4"]
)
# Out:
# Downloading... : 100%|██████████| 174/174 [1:20:13<00:00, 27.67s/ itens]
# Successfully download 174 files to AMZ1-WFI-L4-SR-1
# Building BAND4 mosaic using 10 scenes from the AMZ1-WFI-L4-SR-1
# Building CMASK mosaic using 10 scenes from the AMZ1-WFI-L4-SR-1
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 4 files
# Successfully merged 10 files
# Clipped raster saved to: /media/sansigolo/67f68fb6-8f0b-4be2-8fdf-a1cd72d22aad/sansigolo/smosaic/output/mosaic-amz1-band4-minas-gerais-5m.tif
